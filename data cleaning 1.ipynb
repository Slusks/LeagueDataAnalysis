# %%
import csv
import pathlib as Path
import pprint

file = Path.Path(r'C:\Users\sam\Desktop\ScrapeTest\sql\sheets\SURL.csv')

# %%
import pandas as pd
import csv
import pathlib as Path
import pprint
from collections import Counter
#file = Path.Path(r'C:\Users\sam\Desktop\ScrapeTest\sql\sheets\eURL.csv')
file = Path.Path(r'F:\LeagueStats\scraping\LeagueDataAnalysis\url_matching_table.csv')
file2 = Path.Path(r'F:\LeagueStats\scraping\LeagueDataAnalysis\url_matching_table_no_empty.csv')

df = pd.read_csv(file)


eurls = list(df.url)
surls = list(df.SURL)
gameids = list(df.gameid)

df
# Out:
#                                                       url           gameid  \
# 0       http://matchhistory.na.leagueoflegends.com/en/...  ESPORTSTMNT03/1
# 1       http://matchhistory.na.leagueoflegends.com/en/...  ESPORTSTMNT03/1
# 2       http://matchhistory.na.leagueoflegends.com/en/...  ESPORTSTMNT03/1
# 3       http://matchhistory.na.leagueoflegends.com/en/...  ESPORTSTMNT03/1
# 4       http://matchhistory.na.leagueoflegends.com/en/...  ESPORTSTMNT03/1
# ...                                                   ...              ...
# 514569  http://matchhistory.na.leagueoflegends.com/en/...  TRNA1/100133034
# 514570  http://matchhistory.na.leagueoflegends.com/en/...  TRNA1/100133034
# 514571  http://matchhistory.na.leagueoflegends.com/en/...  TRNA1/100133034
# 514572  http://matchhistory.na.leagueoflegends.com/en/...  TRNA1/100133034
# 514573  http://matchhistory.na.leagueoflegends.com/en/...  TRNA1/100133034
#
#                                                      SURL
# 0       http://matchhistory.na.leagueoflegends.com/en/...
# 1       http://matchhistory.na.leagueoflegends.com/en/...
# 2       http://matchhistory.na.leagueoflegends.com/en/...
# 3       http://matchhistory.na.leagueoflegends.com/en/...
# 4       http://matchhistory.na.leagueoflegends.com/en/...
# ...                                                   ...
# 514569                                                NaN
# 514570                                                NaN
# 514571                                                NaN
# 514572                                                NaN
# 514573                                                NaN
#
# [514574 rows x 3 columns]

# %%
df_clean = pd.read_csv(file)
df.to_csv(file2, index=False)

# %%
raw_eurls = list(df.url)
raw_surls = list(df.SURL)
raw_gameids = list(df.gameid)

print(len(eurls))

print(len(surls))

print(len(gameids))

lists = [eurls, surls, gameids]



#number of non-strings in eurls is 1212
#number of non-strings in surls is 102,195
#number of non-strings in gameids is 132
#print(typelist)

eurls = [i for i in raw_eurls if type(i) == str]
surls = [i for i in raw_surls if type(i) == str]
gameids = [i for i in raw_gameids if type(i) == str]

print(len(eurls))
print(len(surls))
print(len(gameids))


#print(len(set(eurls)))
#print(len(set(surls)))
#print(len(set(gameids)))
# Out:
# 514574
# 514574
# 514574
# 513362
# 412379
# 514442

# %%
## THIS IS WHERE IM WORKING FROM
#Takes about 5 minutes to run
G = set(gameids)
S = set(surls)
E = set(eurls)

#G = gameids
#S = surls
#E = eurls

dict_list = []
count = 0
dict_list = [{'eurl': e, 'surl': s} for e in E for s in S if e in s] 
# The only problem with this method is that lpl records that end in a 3 digit number, example 438, have the potential to be grouped with
# lpl records that have longer versions of that value, example 4381, 4382, 4383


df2 = pd.DataFrame(dict_list)
df2
#this took 284 minutes to run and produced 5,242,700 rows when run on the full lists and not the sets
# Out:
#                                                     eurl  \
# 0      https://matchhistory.na.leagueoflegends.com/en...
# 1      https://matchhistory.na.leagueoflegends.com/en...
# 2      https://matchhistory.na.leagueoflegends.com/en...
# 3      http://matchhistory.na.leagueoflegends.com/en/...
# 4      http://matchhistory.na.leagueoflegends.com/en/...
# ...                                                  ...
# 37610  https://matchhistory.na.leagueoflegends.com/en...
# 37611        https://lpl.qq.com/es/stats.shtml?bmid=4763
# 37612        https://lpl.qq.com/es/stats.shtml?bmid=6366
# 37613  https://matchhistory.br.leagueoflegends.com/pt...
# 37614  http://matchhistory.na.leagueoflegends.com/en/...
#
#                                                     surl
# 0      https://matchhistory.na.leagueoflegends.com/en...
# 1      https://matchhistory.na.leagueoflegends.com/en...
# 2      https://matchhistory.na.leagueoflegends.com/en...
# 3      http://matchhistory.na.leagueoflegends.com/en/...
# 4      http://matchhistory.na.leagueoflegends.com/en/...
# ...                                                  ...
# 37610  https://matchhistory.na.leagueoflegends.com/en...
# 37611        https://lpl.qq.com/es/stats.shtml?bmid=4763
# 37612        https://lpl.qq.com/es/stats.shtml?bmid=6366
# 37613  https://matchhistory.br.leagueoflegends.com/pt...
# 37614  http://matchhistory.na.leagueoflegends.com/en/...
#
# [37615 rows x 2 columns]

# %%
urlrec = Path.Path(r'F:\LeagueStats\scraping\LeagueDataAnalysis\urlrec.csv')
df2 = df2.drop_duplicates(subset=['eurl'])
df2.surl = df2.eurl.apply(lambda x: df2['eurl'][:-1] if len(x) == 42 else x) #THIS DID NOT DO WHAT I WANTED IT TO DO.
df2.to_csv(urlrec, index=False, line_terminator='\n')
### If table doesn't load into sql correctly, use notepad++ to check encoding
#lpl short url is 42 characters, lpl long url is 43 characters
#need to cut last character off of surl

# %%
df2.loc[:10]
length = 1000
for i in df2.eurl:
    if len(i) < length:
        length = len(i)
        shorted = i
        id = list(df2.eurl).index(i)

print(shorted, id )
# Out:
# https://lpl.qq.com/es/stats.shtml?bmid=804 13

# %%
df2.surl = df2.eurl.apply(lambda x: df2['eurl'][:-1] if len(x) == 42 else x)

# %%
df2.loc[13]
# Out:
# eurl           https://lpl.qq.com/es/stats.shtml?bmid=804
# surl    0        https://matchhistory.na.leagueoflegen...
# Name: 13, dtype: object
